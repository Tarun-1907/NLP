# %%
from moviepy.editor import VideoFileClip

def extract_audio(video_file, audio_file):
    video_clip = VideoFileClip(video_file)
    audio_clip = video_clip.audio
    audio_clip.write_audiofile(audio_file)
    video_clip.close()

video_file = "/content/ivdd.mp4"
audio_file = "output_audio.wav"

extract_audio(video_file, audio_file)
# Out:
# MoviePy - Writing audio in output_audio.wav
# MoviePy - Done.

# %%
# !pip install transformers
from transformers import pipeline

# %%
speech_recognition = pipeline("automatic-speech-recognition", model="openai/whisper-large-v3")
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.90k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# ...

# %%
audio_path = "/content/output_audio.wav"
with open(audio_path, "rb") as audio_file:
    audio_bytes = audio_file.read()

transcription = speech_recognition(audio_bytes)

# %%
print(transcription)
# Out:
# {'text': ' अगर मैं एक और वन लगाता हूँ, तो तीन आएगा यहाँ पर, जोकि जो वन है वो तीन बार आ रहा है इस लिस्ट के अंदर, ठीक है तो देखो तीन यहाँ पर आपको देखने को मिलेगा, यह count method था, इसके बाद एक copy method था, लेकिन copy method को समझाने के लिए मैं एक चीज़ आपको दिखाना चाहता हूँ, अगर मान लो कि मैं कुछ ऐसा करता हूँ, मैं कहता हूँ M is equal to L, अब मैं करता हूँ M0 is equal to 0, ठीक है, और इसके बाद मैं L को print करता हूँ, तो आप लोग अगर किसी दूसरी programming language से आ रहे हो, या फिर आप बहुत ही layman terms में इसको evaluate और manipulate करने की को झाल'}

# %%
 # !pip install git+https://github.com/openai/whisper.git
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-d2zrk1in
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-d2zrk1in
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 10.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...

# %%
 # !sudo apt update && sudo apt installffmpeg
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [825 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Fetched 1,059 kB in 1s (833 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# ...

# %%
# !apt list --upgradable
# Out:
# Listing... Done
# base-files/jammy-updates 12ubuntu4.6 amd64 [upgradable from: 12ubuntu4.4]
# bash/jammy-updates,jammy-security 5.1-6ubuntu1.1 amd64 [upgradable from: 5.1-6ubuntu1]
# binutils-common/jammy-updates,jammy-security 2.38-4ubuntu2.6 amd64 [upgradable from: 2.38-4ubuntu2.3]
# binutils-x86-64-linux-gnu/jammy-updates,jammy-security 2.38-4ubuntu2.6 amd64 [upgradable from: 2.38-4ubuntu2.3]
# binutils/jammy-updates,jammy-security 2.38-4ubuntu2.6 amd64 [upgradable from: 2.38-4ubuntu2.3]
# bsdutils/jammy-updates,jammy-security 1:2.37.2-4ubuntu3.4 amd64 [upgradable from: 1:2.37.2-4ubuntu3]
# coreutils/jammy-updates 8.32-4.1ubuntu1.2 amd64 [upgradable from: 8.32-4.1ubuntu1]
# cuda-compat-12-2/unknown 535.161.08-1 amd64 [upgradable from: 535.129.03-1]
# cuda-keyring/unknown 1.1-1 all [upgradable from: 1.0-1]
# cuda-toolkit-12-config-common/unknown 12.4.127-1 all [upgradable from: 12.3.52-1]
# cuda-toolkit-config-common/unknown 12.4.127-1 all [upgradable from: 12.3.52-1]
# ...

# %%
 # !whisper "output_audio.wav" --model large

# %%
# !whisper -h
# Out:
# usage: whisper [-h] [--model MODEL] [--model_dir MODEL_DIR] [--device DEVICE]
#                [--output_dir OUTPUT_DIR] [--output_format {txt,vtt,srt,tsv,json,all}]
#                [--verbose VERBOSE] [--task {transcribe,translate}]
# ...
